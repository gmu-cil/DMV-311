# %% [markdown]
# #### Washington DC Datetime:
# 1. Import required libraries
# 2. read the formatted file in a dataframe

# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv('C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\Formatted_311_Washington_DC_2019.csv')

# %% [markdown]
# 3. The default datetime in DC is 1970-01-01 00:00:00+00:00. Changing it to null to maintain standard practice for all counties
# 4. Convert ZipCode to Int
# 5. Convert 'Date Request Opened', 'Date Service Due', 'Date Request Resolved' to datetime.

# %%
df["Date Request Opened"]= df["Date Request Opened"].replace(pd.to_datetime('1970-01-01 00:00:00+00:00'), "NULL")
df["Date Service Due"]= df["Date Service Due"].replace(pd.to_datetime('1970-01-01 00:00:00+00:00'), "NULL")
df["Date Request Resolved"]= df["Date Request Resolved"].replace(pd.to_datetime('1970-01-01 00:00:00+00:00'), "NULL")
df['ZipCode']= df['ZipCode'].astype('Int64')
df["Date Request Opened"] = pd.to_datetime(df["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
df["Date Service Due"] = pd.to_datetime(df["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
df["Date Request Resolved"] = pd.to_datetime(df["Date Request Resolved"], format ="%Y-%m-%d %H:%M:%S")

# %% [markdown]
# 6. Save it as csv file

# %%
df_DC.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\final311_Washington_DC_2019.csv', index = False)

# %%
df_DC.dtypes
# Out:
# Service Request ID           object
# Service Type                 object
# Service Description          object
# Organization Responsible     object
# Date Request Opened          object
# Date Service Due             object
# Date Request Resolved        object
# Status                       object
# Details                      object
# Street Address               object
# City                         object
# State                        object
# ZipCode                     float64
# Latitude                    float64
# Longitude                   float64
# dtype: object

# %% [markdown]
# ### Montgomery County Datetime
# 1. Read it into a dataframe

# %%
import numpy as np
df_MC = pd.read_csv('C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\final_311_Montgomery County_MD_2019.csv')

# %% [markdown]
# 2. Change latitude/longitude to NULL

# %%
df_MC["Latitude"] = df_MC["Latitude"].replace(np.nan,'NULL')
df_MC["Longitude"] = df_MC["Longitude"].replace(np.nan,'NULL')
df_MC
# Out:
#         Service Request ID                                     Service Type  \
# 0               1377072702                   Highway Services, Snow Removal
# 1               1377076280  Environmental Code Enforcement, Illegal Dumping
# 2               1377080766                 Solid Waste, Scrap Metal Request
# 3               1377086396                Children Youth and Families, OESS
# 4               1377086517                 Solid Waste, Scrap Metal Request
# ...                    ...                                              ...
# 555504          1404678982               Tree Maintenance, Pruning Requests
# 555505          1404878784               Tree Maintenance, Pruning Requests
# 555506          1404984988               Tree Maintenance, Pruning Requests
# 555507          1405232010               Tree Maintenance, Pruning Requests
# 555508          1407284188               Tree Maintenance, Pruning Requests
#
# ...

# %% [markdown]
# 3. Convert 'Date Request Opened' and 'Date Request Due' to Datetime

# %%
from datetime import datetime
df_MC["Date Request Opened"] = pd.to_datetime(df_MC["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
df_MC["Date Service Due"] = pd.to_datetime(df_MC["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")

# %%
import numpy as np

temp=df_MC['Date Request Resolved'].iloc[df_MC.loc[df_MC['Date Request Resolved'].isnull()].index.to_numpy()]

# %% [markdown]
# 4.For 'Date Request Resolved' some values are NAN, to handle that used the below condition

# %%
import math
df_MC["Date Request Resolved"] =df_MC["Date Request Resolved"].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d %H:%M:%S') if not str(x)=='nan' else 'NULL')

# %% [markdown]
# 5. Save it as a CSV

# %%
df_MC.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\FINAL\\final_311_Montgomery County_MD_2019.csv', index = False)

# %% [markdown]
# ### PG County Datetime
# 1. Import the formatted file into a dataframe

# %%
import pandas as pd
df_PG = pd.read_csv('C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\Formatted_311_Prince George County_MD_2019.csv')
df_PG
# Out:
#       Service Request ID                      Service Type  \
# 0            19-00104025      Public Safety Communications
# 1            19-00104020       Traffic Operations Division
# 2            19-00104015                     Rva - General
# 3            19-00069381             Construction Division
# 4            19-00105069            Field Activities - Amd
# ...                  ...                               ...
# 57548        19-00057799  Single Family (Code Enforcement)
# 57549        19-00075268         Special Services Division
# 57550        19-00075307         Special Services Division
# 57551        19-00079439  Single Family (Code Enforcement)
# 57552        19-00089942  Single Family (Code Enforcement)
#
#                          Service Description  \
# 0                PSC Audio Recording Request
# 1             Traffic Signs - Repair/Replace
# 2                         Parking Complaints
# 3                        Roadway Emergencies
# ...

# %% [markdown]
# 2. Convert 'Date Request Opened', 'Date Service Due' to Datetime. All Date Request Resolved are NAN.

# %%
df_PG["Date Request Opened"] = pd.to_datetime(df_PG["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
df_PG["Date Service Due"] = pd.to_datetime(df_PG["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
#df_PG["Date Request Resolved"] = 'NULL'#pd.to_datetime(df_PG["Date Request Resolved"], format ="%Y-%m-%d %H:%M:%S")

# %%
df_PG
# Out:
#       Service Request ID                      Service Type  \
# 0            19-00104025      Public Safety Communications
# 1            19-00104020       Traffic Operations Division
# 2            19-00104015                     Rva - General
# 3            19-00069381             Construction Division
# 4            19-00105069            Field Activities - Amd
# ...                  ...                               ...
# 57548        19-00057799  Single Family (Code Enforcement)
# 57549        19-00075268         Special Services Division
# 57550        19-00075307         Special Services Division
# 57551        19-00079439  Single Family (Code Enforcement)
# 57552        19-00089942  Single Family (Code Enforcement)
#
#                          Service Description  \
# 0                PSC Audio Recording Request
# 1             Traffic Signs - Repair/Replace
# 2                         Parking Complaints
# 3                        Roadway Emergencies
# ...

# %% [markdown]
# 3. Save it into a csv

# %%
df_PG.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\final_311_Prince George County_MD_2019.csv', index = False)

# %% [markdown]
# #### Arlington County Datetime
# 1. We have to read it using a reader, as in the dataset there are "\" which gives trouble while importing into Database

# %%
import csv
with open('C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\Formatted_MyArlington_Arlington_VA_2020.csv', newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    df_AC = pd.DataFrame(reader)

# %% [markdown]
# 2. Drop Unnecessary columns

# %%
df_AC=df_AC.drop(columns=6)
df_AC.columns = df_AC.iloc[0]
df_AC=df_AC.drop(df_AC.index[[0]])

# %% [markdown]
# 3. Replace '\' with '' in the data

# %%
df_AC['Service Description'] = df_AC['Service Description'].replace({'\"':''}, regex=True)

# %% [markdown]
# 4. Convert 'Date Request Opened', 'Date Service Due 'to Datetime

# %%
df_AC["Date Request Opened"] = pd.to_datetime(df_AC["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
df_AC["Date Service Due"] = pd.to_datetime(df_AC["Date Request Opened"], format ="%Y-%m-%d %H:%M:%S")
#df_AC["Date Request Resolved"] = pd.to_datetime(df_PG["Date Request Resolved"], format ="%Y-%m-%d %H:%M:%S")

# %% [markdown]
# 5. Save it as a csv

# %%
df_AC.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\final_MyArlington_Arlington_VA_2020.csv', index = False, encoding='utf-8')
