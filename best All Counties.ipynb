# %%
#Code to fetch DC Data
import pandas as pd
df_test = pd.read_csv('C:\\Users\\samri\\Downloads\\311_Washington_DC_2019.csv')

df_test= df_test.drop(columns = ['OBJECTID','X', 'Y', 'SERVICECODE','SERVICECALLCOUNT', 'SERVICEORDERDATE','INSPECTIONFLAG','INSPECTIONDATE','INSPECTORNAME', 'STATUS_CODE', 'PRIORITY', 'XCOORD', 'YCOORD', 'MARADDRESSREPOSITORYID', 'WARD' ])
df_test["ADDDATE"] = pd.to_datetime(df_test["ADDDATE"])
df_test["RESOLUTIONDATE"] = pd.to_datetime(df_test["RESOLUTIONDATE"])
df_test["SERVICEDUEDATE"] = pd.to_datetime(df_test["SERVICEDUEDATE"])
df_test.rename(columns = {'SERVICECODEDESCRIPTION' : 'Service Description', 'SERVICETYPECODEDESCRIPTION' : 'Service Type', 'ORGANIZATIONACRONYM' : 'Organization Responsible', 'ADDDATE' : 'Date Request Opened', 'RESOLUTIONDATE' : 'Date Request Resolved' , 'SERVICEDUEDATE': 'Date Service Due','SERVICEORDERSTATUS' : 'Status', 'SERVICEREQUESTID' : 'Service Request ID', 'STREETADDRESS' : 'Street Address', 'LATITUDE' : 'Latitude', 'LONGITUDE': 'Longitude', 'CITY' : 'City', 'STATE':'State', 'ZIPCODE' : 'ZipCode', 'DETAILS':'Details' }, inplace = True)
df_test = df_test[['Service Request ID', 'Service Type', 'Service Description', 'Organization Responsible', 'Date Request Opened', 'Date Service Due', 'Date Request Resolved', 'Status', 'Details','Street Address', 'City', 'State', 'ZipCode', 'Latitude', 'Longitude']]
df_2 =[]
df_2=df_test['Street Address'].str.split(",",expand=True)
df_test['Street Address'] = df_2[0]
df_test.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\TT_Formatted_311_Washington_DC_2019.csv', index = False)

df_test
# Out:
# C:\Users\samri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Service Request ID                                       Service Type  \
# 0             19-00784984          SWMA- Solid Waste Management Admistration
# 1             19-00784985           Transportation Operations Administration
# 2             19-00785007           Transportation Operations Administration
# 3             19-00785008  PEMA- Parking Enforcement Management Administr...
# 4             19-00784986          SWMA- Solid Waste Management Admistration
# ...                   ...                                                ...
# 365006        19-00096558              Dept of Consumer & Regulatory Affairs
# 365007        19-00099202              Dept of Consumer & Regulatory Affairs
# ...

# %%
#df_MC = pd.read_csv('C:\\Users\\samri\\Downloads\\311_Montgomery County_MD_2020.csv',index_col = 0)
df_MC = pd.read_csv('C:\\Users\\samri\\Downloads\\311_Montgomery Test.csv',index_col = 0)

from datetime import datetime, timedelta
df_MC["Date Service Due"] = pd.to_datetime(df_MC["Opened"])  + pd.to_timedelta(df_MC["Attached Solution SLA Days"],unit='d')
df_MC['Service Type'] = df_MC['Area'].fillna('') + ", " + df_MC['Sub-Area'].fillna('')
df_MC["Opened"] = pd.to_datetime(df_MC["Opened"])

df_MC["Closed"] = pd.to_datetime(df_MC["Closed"])
df_MC= df_MC.drop(columns = ['Congressional District', 'Congressional Member', 'Council District', 'Council Member Name','Changed Date','# of Days Open','SLA Yes', 'SLA No', 'Attached Solution SLA Days','Within SLA Windows' ,'opened_date','Source','Election District','Maryland State District','Area','Sub-Area'])
df_MC.rename(columns = {'SR ID': 'Service Request ID','Opened': 'Date Request Opened', 'Closed':'Date Request Resolved','Attached Solution (Topic)':'Service Description', 'Department':'Organization Responsible','Zip Code' :'ZipCode'},inplace = True)
df_MC = df_MC[['Service Request ID', 'Service Type', 'Service Description', 'Organization Responsible', 'Date Request Opened', 'Date Service Due', 'Date Request Resolved', 'Status','City', 'State', 'ZipCode']]

df_MC
# Out:
#     Service Request ID                       Service Type  \
# 0           1421822412                 Code Enforcement,
# 1           1407530213           Solid Waste, Cart Repair
# 2           1407534460           Solid Waste, Bin Pick-Up
# 3           1407797304           Solid Waste, Bin Pick-Up
# 4           1407683077  Children Youth and Families, OESS
# 5           1407693231  Children Youth and Families, OESS
# 6           1407695912           Solid Waste, Cart Repair
# 7           1407696093           Solid Waste, Cart Repair
# 8           1407697164           Solid Waste, Cart Repair
# 9           1407699751       Solid Waste, Bin Request-New
# 10          1407801524    Solid Waste, Bulk Trash Request
# 11          1407703312           Solid Waste, Cart Repair
# 12          1407708866       Solid Waste, Bin Request-New
# 13          1418156532            Solid Waste, Literature
# 14          1407717937           Solid Waste, Cart Repair
# ...

# %%
df_MC.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\try_311_Montgomery County_MD_2020.csv', index = False)

# %%
df_MC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Service Request ID        20 non-null     int64
#  1   Service Type              20 non-null     object
#  2   Service Description       20 non-null     object
#  3   Organization Responsible  20 non-null     object
#  4   Date Request Opened       20 non-null     datetime64[ns]
#  5   Date Service Due          20 non-null     datetime64[ns]
#  6   Date Request Resolved     20 non-null     datetime64[ns]
#  7   Status                    20 non-null     object
#  8   City                      19 non-null     object
#  9   State                     20 non-null     object
#  10  ZipCode                   19 non-null     float64
# dtypes: datetime64[ns](3), float64(1), int64(1), object(6)
# memory usage: 1.9+ KB

# %%
import pandas as pd
import numpy as np
df_PG = pd.read_csv('C:\\Users\\samri\\Downloads\\311_Prince George County_MD_2019.csv',index_col = 0)
#df_PG = pd.read_csv('C:\\Users\\samri\\Downloads\\try_311_Prince George County_MD_2019.csv',index_col = 0)
df_PG= df_PG.drop(columns = ['SLA','Location','TNI Area Description', 'opened_date'])
df_PG['Latitude']= df_PG['Latitude'].astype(float)
df_PG['Longitude']= df_PG['Longitude'].astype(float)
df_PG['Latitude'] = df_PG['Latitude'].replace(np.nan, 0, regex=True)
df_PG['Longitude'] = df_PG['Longitude'].replace(np.nan, 0, regex=True)
df_PG["Date Request Opened"] = pd.to_datetime(df_PG["Date Request Opened"])
df_PG.rename(columns = {'Request Name' : 'Service Description', 'Service Group' : 'Service Type', 'Agency Responsible' : 'Organization Responsible', 'Request Status' : 'Status', 'Service Request #' : 'Service Request ID'}, inplace = True)
df_PG = df_PG[['Service Request ID', 'Service Type', 'Service Description', 'Organization Responsible', 'Date Request Opened','Status','Latitude', 'Longitude']]
df_PG.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\Formatted_311_Prince George County_MD_2019.csv', index = False)
#df_PG.to_csv(r'C:\\Users\\samri\\OneDrive\\Documents\\Research work\\DATA\\try_311_Prince George County_MD_2019.csv', index = False)

df_PG
# Out:
#       Service Request ID                      Service Type  \
# 0            19-00104025      Public Safety Communications
# 1            19-00104020       Traffic Operations Division
# 2            19-00104015                     Rva - General
# 3            19-00069381             Construction Division
# 4            19-00105069            Field Activities - Amd
# ...                  ...                               ...
# 57548        19-00057799  Single Family (Code Enforcement)
# 57549        19-00075268         Special Services Division
# 57550        19-00075307         Special Services Division
# 57551        19-00079439  Single Family (Code Enforcement)
# 57552        19-00089942  Single Family (Code Enforcement)
#
#                          Service Description  \
# 0                PSC Audio Recording Request
# 1             Traffic Signs - Repair/Replace
# 2                         Parking Complaints
# 3                        Roadway Emergencies
# ...

# %%
df_PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57553 entries, 0 to 57552
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Service Request ID        57553 non-null  object
#  1   Service Type              57553 non-null  object
#  2   Service Description       57553 non-null  object
#  3   Organization Responsible  57553 non-null  object
#  4   Date Request Opened       57553 non-null  datetime64[ns]
#  5   Status                    57553 non-null  object
#  6   Latitude                  57553 non-null  float64
#  7   Longitude                 57553 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 4.0+ MB
